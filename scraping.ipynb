# %%
from bs4  import BeautifulSoup
import requests
import pandas as pd

# %%
url='https://www.wong.pe/abarrotes'
page = requests.get(url)
soup= BeautifulSoup(page.content,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html >
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:vtex="http://www.vtex.com.br/2009/vtex-common" xmlns:vtex.cmc="http://www.vtex.com.br/2009/vtex-commerce">
#  <head>
#   <meta content="es-PE" name="language"/>
#   <meta content="PER" name="country"/>
#   <meta content="S/." name="currency"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="#f01612" name="theme-color"/>
#   <link href="https://wongfood.vtexassets.com/arquivos/wong_icon_32.png?v=636110939404970000" rel="icon"/>
#   <link href="https://wongfood.vtexassets.com/arquivos/wong_icon_32.png?v=636110939404970000" rel="icon" sizes="32x32"/>
#   <link href="https://wongfood.vtexassets.com/arquivos/wong_icon_152.png?v=636110939411530000" rel="apple-touch-icon-precomposed"/>
#   <meta content="8bsIVQ7jjqfNnVLwnfwJLB-KehbLZweX7o-m5qBU67M" name="google-site-verification"/>
# ...

# %%
#abarrotes

ab=soup.find_all("li",class_='comprar-abarrotes-online')
print(ab)
# Out:
# [<li class="comprar-abarrotes-online" layout="19ccd66b-b568-43cb-a106-b52f9796f5cd">
# <div class="product-item product-item--427" data-brand="Primor" data-category="https://www.wong.pe/abarrotes/aceites/aceites-vegetales" data-id="427" data-index="-1" data-name="Aceite Vegetal Primor Premium 900ml" data-price="S/. 12.19" data-refid="-1" data-sku="427" data-uri="https://www.wong.pe/aceite-vegetal-primor-premium-900ml-3198/p">
# <div class="product-item__data" style="display: none">
# <div class="product-item__data--product">
# <div class="product-field product_field_471 product-field-type_2">
# ProductData
# <ul>
# ...

# %%
ab1=soup.find("li",class_='comprar-abarrotes-online')

# %%
abarrotes= soup.find("li",class_='comprar-abarrotes-online')
data_name= abarrotes.find('div')
data_name
# Out:
# <div class="product-item product-item--427" data-brand="Primor" data-category="https://www.wong.pe/abarrotes/aceites/aceites-vegetales" data-id="427" data-index="-1" data-name="Aceite Vegetal Primor Premium 900ml" data-price="S/. 12.19" data-refid="-1" data-sku="427" data-uri="https://www.wong.pe/aceite-vegetal-primor-premium-900ml-3198/p">
# <div class="product-item__data" style="display: none">
# <div class="product-item__data--product">
# <div class="product-field product_field_471 product-field-type_2">
# ProductData
# <ul>
# <li allow_notes":true"allow_substitute":true"cart_limit":"24""brandname":"primor""brandecomid":"742""measurement_unit":"un""unit_multiplier":1"unit_multiplier_un":0"measurement_unit_selector":false-"="" class="-">{"allow_notes":true,"allow_substitute":true,"cart_limit":"24","brandName":"Primor","brandEcomId":"742","measurement_unit":"un","unit_multiplier":1,"unit_multiplier_un":0,"measurement_unit_selector":false}</li>
# </ul>
# </div>
# </div>
# ...

# %%
for i in abarrotes:
    print (i)
# Out:
# <div class="product-item product-item--427" data-brand="Primor" data-category="https://www.wong.pe/abarrotes/aceites/aceites-vegetales" data-id="427" data-index="-1" data-name="Aceite Vegetal Primor Premium 900ml" data-price="S/. 12.19" data-refid="-1" data-sku="427" data-uri="https://www.wong.pe/aceite-vegetal-primor-premium-900ml-3198/p">
# <div class="product-item__data" style="display: none">
# <div class="product-item__data--product">
# <div class="product-field product_field_471 product-field-type_2">
# ProductData
# <ul>
# <li allow_notes":true"allow_substitute":true"cart_limit":"24""brandname":"primor""brandecomid":"742""measurement_unit":"un""unit_multiplier":1"unit_multiplier_un":0"measurement_unit_selector":false-"="" class="-">{"allow_notes":true,"allow_substitute":true,"cart_limit":"24","brandName":"Primor","brandEcomId":"742","measurement_unit":"un","unit_multiplier":1,"unit_multiplier_un":0,"measurement_unit_selector":false}</li>
# </ul>
# </div>
# </div>
# ...

# %%
abarrotes= soup.find("li",class_='comprar-abarrotes-online')
data_brand_ab= abarrotes.find('div')
data_brand_ab.get('data-name')
# Out:
# 'Aceite Vegetal Primor Premium 900ml'

# %%
for elemento in data_brand_ab: print (elemento)
# Out:
# <div class="product-item__data" style="display: none">
# <div class="product-item__data--product">
# <div class="product-field product_field_471 product-field-type_2">
# ProductData
# <ul>
# <li allow_notes":true"allow_substitute":true"cart_limit":"24""brandname":"primor""brandecomid":"742""measurement_unit":"un""unit_multiplier":1"unit_multiplier_un":0"measurement_unit_selector":false-"="" class="-">{"allow_notes":true,"allow_substitute":true,"cart_limit":"24","brandName":"Primor","brandEcomId":"742","measurement_unit":"un","unit_multiplier":1,"unit_multiplier_un":0,"measurement_unit_selector":false}</li>
# </ul>
# </div>
# </div>
# <div class="product-item__data--sku">
# <div class="product-field product_field_472 product-field-type_2">
# SkuData
# <ul>
# ...

# %%
lista_data_brand_ab=list()
for i in abarrotes: lista_data_brand_ab.append(i)
lista_data_brand_ab
# Out:
# ['\n',
#  <div class="product-item product-item--427" data-brand="Primor" data-category="https://www.wong.pe/abarrotes/aceites/aceites-vegetales" data-id="427" data-index="-1" data-name="Aceite Vegetal Primor Premium 900ml" data-price="S/. 12.19" data-refid="-1" data-sku="427" data-uri="https://www.wong.pe/aceite-vegetal-primor-premium-900ml-3198/p">
#  <div class="product-item__data" style="display: none">
#  <div class="product-item__data--product">
#  <div class="product-field product_field_471 product-field-type_2">
#  ProductData
#  <ul>
#  <li allow_notes":true"allow_substitute":true"cart_limit":"24""brandname":"primor""brandecomid":"742""measurement_unit":"un""unit_multiplier":1"unit_multiplier_un":0"measurement_unit_selector":false-"="" class="-">{"allow_notes":true,"allow_substitute":true,"cart_limit":"24","brandName":"Primor","brandEcomId":"742","measurement_unit":"un","unit_multiplier":1,"unit_multiplier_un":0,"measurement_unit_selector":false}</li>
#  </ul>
#  </div>
# ...

# %%
abarrotes= soup.find("li",class_='comprar-abarrotes-online')
# data_brand_ab= abarrotes.find('div').get('data-brand')


data_brand_ab=list()

for i in abarrotes :
    if i.get('data-name')!= None:
        data_brand_ab.append(i.get('data-name'))
    continue

print(data_brand_ab)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\yoe_1\OneDrive\Escritorio\CARPETA DOCUMENTOS\PRACTICANDO CON PYTHON\scraping.ipynb Celda 8 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/yoe_1/OneDrive/Escritorio/CARPETA%20DOCUMENTOS/PRACTICANDO%20CON%20PYTHON/scraping.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a> data_brand_ab=list()
#       <a href='vscode-notebook-cell:/c%3A/Users/yoe_1/OneDrive/Escritorio/CARPETA%20DOCUMENTOS/PRACTICANDO%20CON%20PYTHON/scraping.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a> for i in abarrotes :
# ----> <a href='vscode-notebook-cell:/c%3A/Users/yoe_1/OneDrive/Escritorio/CARPETA%20DOCUMENTOS/PRACTICANDO%20CON%20PYTHON/scraping.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a>     if i.get('data-name')!= None:
# ...

# %%
# Lista de Marcas

data_brand= soup.find_all('div')

brands=list()

for i in data_brand :
    if i.get('data-brand')!= None:
        brands.append(i.get('data-brand'))
    continue

print(brands)
# Out:
# ['Thomas', 'Practika', 'Bosch', 'Imaco', 'Taurus', 'Record', 'Bosch', 'Coldex', 'Thomas', 'Imaco', 'Oster', 'Thomas', 'Primor', 'Don Vittorio', 'Cuisine & Co', 'Emsal', 'Field', 'San Jorge', 'Nestlé', 'Costeño', 'Valle Norte', 'Costeño', 'Florida', 'Field', 'Chaplin', 'Valle Norte', 'Florida', 'Inka Chips', 'Cuisine & Co', 'Sanissimo']

# %%
abarrotes=list()
for i in ab:
    abarrotes.append(i.text)

# %%
for prod in soup.find_all("li",class_='comprar-abarrotes-online'):
    n= prod.find("div", class_="product-item")
    print(n.get('data-name'))
# Out:
# Aceite Vegetal Primor Premium 900ml
# Fideo Spaghetti Don Vittorio 950g
# Aceite Vegetal Cuisine&Co Botella 900 ml
# Sal de Mesa Marina Emsal Bolsa 1 kg
# Galletas Sabor Vainilla Field Paquete 37 g Pack 6 unid
# Galletas San Jorge Soda Pack 7un
# Galletas Morochas 30g Pack 6un
# Lenteja Costeño Bolsa 500 g
# Arroz Gran Reserva Extra Valle Norte Bolsa 5 Kg
# Arroz Extra Costeño 5kg
# Filete de Atún en Aceite Florida 150g
# Sixpack Galletas Coronita con Crema de Chocolate 36g
# Galletas Dulces Bolsa 90 g
# Filete de Atún en Agua Florida 140g
# Papas Fritas Crujientes Saladas Inka Chips 142g
# Lenteja Bebé Cuisine & Co Bolsa 500 gr
# Galletas de Maíz Horneadas Sin Gluten Salmas Sanissimo Caja 144 g
