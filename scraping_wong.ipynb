# %%
from bs4  import BeautifulSoup
import requests
import pandas as pd

# %%
url='https://www.wong.pe'
page = requests.get(url)
soup= BeautifulSoup(page.content,'html.parser')

# %%
css_soup= BeautifulSoup('<div class="product-item product-item"></div>','html.parser')
css_soup.find_all("div", class_="product-item")
# Out:
# [<div class="product-item product-item"></div>]

# %%
seleccion=soup.select("div.product-item")
seleccion
# Out:
# [<div class="product-item product-item--561620" data-brand="Taurus" data-category="https://www.wong.pe/electrohogar/electrodomesticos/cafeteras" data-id="561620" data-index="-1" data-name="Taurus Cafetera de Filtro Florencia 12 Tazas" data-price="S/. 229.90" data-refid="-1" data-sku="39159442" data-uri="https://www.wong.pe/taurus-cafetera-de-filtro-florencia-12-tazas/p">
#  <div class="product-item__data" style="display: none">
#  <div class="product-item__data--product">
#  <div class="product-field product_field_471 product-field-type_2">
#  ProductData
#  <ul>
# ...

# %%
#Obteniendo el elemento 
x=soup.find_all('div',class_="product-item")#.get('data-price')

# %%
# nombre de productos   
data_name=list()
data_brand=list()
data_price=list()

for elemento in x: 
    data_name.append(elemento.get('data-name')) 
    data_brand.append(elemento.get('data-brand')) 
    data_price.append(elemento.get('data-price'))

# %%
df=pd.DataFrame({'Marca':data_brand ,'Nombre':data_name, 'Precio':data_price})
df
# Out:
#            Marca                                             Nombre  \
# 0         Taurus       Taurus Cafetera de Filtro Florencia 12 Tazas
# 1       Practika           Practika Batidora de Inmersión Robot 250
# 2          Bosch                Bosch Picador MMR08R2 400W - 800 Lt
# 3            NEX                          Nex Plancha a Vapor SI010
# 4         Record                   Record Cafetera de Filtro 1.8 Lt
# 5         Thomas           Thomas Hervidor Eléctrico TH-4340 1.7 Lt
# 6           Mabe         Mabe Cocina de Pie CMP6030FX0 4 Quemadores
# 7     Electrolux   Electrolux Cocina a Gas EKGW24C2CSTB 4 Hornillas
# 8          Imaco      Imaco Licuadora 1.25 Lt BL4125R 2 Velocidades
# 9           Mabe           Mabe Cocina de Pie TX5110P0 4 Quemadores
# 10        Record                Record Plancha a Vapor CLP100 1200W
# 11        Taurus  Taurus Extractor de Jugos LiquaFruits Pro Comp...
# 12        Primor                Aceite Vegetal Primor Premium 900ml
# ...

# %%
soup.find_all('div',class_="product-item")
# Out:
# [<div class="product-item product-item--36808" data-brand="Record" data-category="https://www.wong.pe/electrohogar/electrodomesticos/exprimidores-y-extractores" data-id="36808" data-index="-1" data-name="Extractor de Jugos Record 2 Velocidades 1L" data-price="S/. 159.00" data-refid="-1" data-sku="36741" data-uri="https://www.wong.pe/extractor-de-jugos-record-2-velocidades-1l-720750/p">
#  <div class="product-item__data" style="display: none">
#  <div class="product-item__data--product">
#  <div class="product-field product_field_471 product-field-type_2">
#  ProductData
#  <ul>
# ...

# %%
soup.find("li",class_='comprar-abarrotes-online')
# Out:
# <li class="comprar-abarrotes-online" layout="19ccd66b-b568-43cb-a106-b52f9796f5cd">
# <div class="product-item product-item--427" data-brand="Primor" data-category="https://www.wong.pe/abarrotes/aceites/aceites-vegetales" data-id="427" data-index="-1" data-name="Aceite Vegetal Primor Premium 900ml" data-price="S/. 12.19" data-refid="-1" data-sku="427" data-uri="https://www.wong.pe/aceite-vegetal-primor-premium-900ml-3198/p">
# <div class="product-item__data" style="display: none">
# <div class="product-item__data--product">
# <div class="product-field product_field_471 product-field-type_2">
# ProductData
# <ul>
# ...

# %%
soup.find_all("li",class_='comprar-abarrotes-online')
# product_inter=
# abarrotes.select('div',class_="product-item")
# Out:
# [<li class="comprar-abarrotes-online" layout="19ccd66b-b568-43cb-a106-b52f9796f5cd">
#  <div class="product-item product-item--427" data-brand="Primor" data-category="https://www.wong.pe/abarrotes/aceites/aceites-vegetales" data-id="427" data-index="-1" data-name="Aceite Vegetal Primor Premium 900ml" data-price="S/. 12.19" data-refid="-1" data-sku="427" data-uri="https://www.wong.pe/aceite-vegetal-primor-premium-900ml-3198/p">
#  <div class="product-item__data" style="display: none">
#  <div class="product-item__data--product">
#  <div class="product-field product_field_471 product-field-type_2">
#  ProductData
#  <ul>
# ...

# %%
from selenium import webdriver
import time

# %%
driver= webdriver.Chrome(executable_path=r'C:\Users\yoe_1\Downloads\chromedriver_win32\chromedriver.exe')
driver.get('https://www.wong.pe/abarrotes')
time.sleep(3)
driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
time.sleep(3)
# Out:
# C:\Users\yoe_1\AppData\Local\Temp\ipykernel_11496\561779605.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome(executable_path=r'C:\Users\yoe_1\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver= webdriver.Chrome(executable_path=r'C:\Users\yoe_1\Downloads\chromedriver_win32\chromedriver.exe')
driver.get('https://www.wong.pe/abarrotes')


SCROLL_PAUSE_TIME = 0.5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
# Out:
# C:\Users\yoe_1\AppData\Local\Temp\ipykernel_11496\1232217604.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome(executable_path=r'C:\Users\yoe_1\Downloads\chromedriver_win32\chromedriver.exe')

# %%
from bs4  import BeautifulSoup
import requests
import pandas as pd

# %%
url='https://www.wong.pe/abarrotes'
page = requests.get(url)
soup= BeautifulSoup(page.content,'html.parser')
for prod in soup.find_all("li",class_='comprar-abarrotes-online'):
    n= prod.find("div", class_="product-item")
    print(n.get('data-name'))
# Out:
# Aceite Vegetal Primor Premium 900ml
# Fideo Spaghetti Don Vittorio 950g
# Aceite Vegetal Cuisine&Co Botella 900 ml
# Sal de Mesa Marina Emsal Bolsa 1 kg
# Galletas Sabor Vainilla Field Paquete 37 g Pack 6 unid
# Galletas San Jorge Soda Pack 7un
# Galletas Morochas 30g Pack 6un
# Lenteja Costeño Bolsa 500 g
# Arroz Gran Reserva Extra Valle Norte Bolsa 5 Kg
# Arroz Extra Costeño 5kg
# Sixpack Galletas Soda Field 32g
# Filete de Atún en Aceite Florida 150g
# Sixpack Galletas Coronita con Crema de Chocolate 36g
# Galletas Dulces Bolsa 90 g
# Filete de Atún en Agua Florida 140g
# Papas Fritas Crujientes Saladas Inka Chips 142g
# Lenteja Cuisine & Co Bolsa 500 gr

# %%
url='https://www.wong.pe/abarrotes'
page = requests.get(url)
soup= BeautifulSoup(page.content,'html.parser')

driver= webdriver.Chrome(executable_path=r'C:\Users\yoe_1\Downloads\chromedriver_win32\chromedriver.exe')
driver.get('https://www.wong.pe/abarrotes')


SCROLL_PAUSE_TIME = 0.5

# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    for prod in soup.find_all("li",class_='comprar-abarrotes-online'):
        n= prod.find("div", class_="product-item")
    
    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
# Out:
# C:\Users\yoe_1\AppData\Local\Temp\ipykernel_11496\1807199932.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver= webdriver.Chrome(executable_path=r'C:\Users\yoe_1\Downloads\chromedriver_win32\chromedriver.exe')

# %%
print(n.get('data-name'))
# Out:
# Lenteja Cuisine & Co Bolsa 500 gr
